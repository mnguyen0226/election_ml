# %% [markdown]
# ### Analyze features of Democrat and Republican Voters

# %%
import pandas as pd

# %%
# Import datasets
dfd = pd.read_excel("edit_summary_stats_with_features.xlsx", "Democrat")
dfr = pd.read_excel("edit_summary_stats_with_features.xlsx", "Republican")

# %%
dfd = dfd.drop('winner', axis=1)
dfr = dfr.drop('winner', axis=1)

# %%
dfd
# Out:
#       inctot  mortamt1  ftotinc  marst_5_freq  marst_6_freq  marst_1_freq  \
# 0    28109.5     812.4  54993.2           9.5          23.5          50.3
# 1    22160.8     991.5  45262.3           5.3          32.4          47.7
# 2    27762.8     944.5  50733.7           7.1          23.7          52.3
# 3    29002.7     786.3  53027.7           8.0          21.7          52.0
# 4    38247.7    1648.9  72823.4           6.1          28.7          50.9
# ..       ...       ...      ...           ...           ...           ...
# 849  28900.8    1066.2  57780.5           4.9          31.1          49.7
# 850  36106.6     969.0  67751.9           4.3          32.4          50.3
# 851  27337.7     794.8  59052.3           7.9          32.5          47.7
# 852  26162.8     770.5  48500.4           6.0          41.9          37.6
# 853  25993.3     657.3  54440.5           7.4          27.4          49.9
#
#      marst_4_freq  marst_3_freq  race_2_freq  race_3_freq  ctz_stat_3_freq  \
# ...

# %%
dfr
# Out:
#       inctot  mortamt1  ftotinc  marst_5_freq  marst_6_freq  marst_1_freq  \
# 0    27222.4     902.2  53308.6           8.3          12.1          63.4
# 1    20951.6     551.7  39712.5           8.7          19.5          54.5
# 2    24017.6     658.6  47650.0          10.5          13.8          60.9
# 3    24870.4     725.1  45575.0           4.9          32.1          51.2
# 4    24039.4     680.1  47208.6           8.5          22.6          52.3
# ..       ...       ...      ...           ...           ...           ...
# 811  29696.5     734.7  61336.5           6.8          22.0          55.7
# 812  26884.0     704.0  52592.7           7.3          24.2          57.1
# 813  28065.5     846.0  63315.2           5.9          26.8          56.6
# 814  38557.0     990.6  80433.1           7.4          20.0          61.5
# 815  25796.1     667.3  49219.4           6.7          28.2          50.3
#
#      marst_4_freq  marst_3_freq  race_2_freq  race_3_freq  ctz_stat_3_freq  \
# ...

# %%
# Average values of important features for Democrat voters
dfd.mean()
# Out:
# inctot                  30289.064520
# mortamt1                 1006.532084
# ftotinc                 61120.358431
# marst_5_freq                6.483255
# marst_6_freq               29.255855
# marst_1_freq               49.449180
# marst_4_freq               10.829391
# marst_3_freq                1.791452
# race_2_freq                12.432201
# race_3_freq                 0.882084
# ctz_stat_3_freq             6.800351
# ctz_stat_2_freq             7.773068
# lang_1_freq                80.774122
# lang_2_freq                19.225878
# educ_attain_2.0_freq       50.443091
# educ_attain_3.0_freq       11.427518
# educ_attain_4.0_freq        1.698478
# empstat_1.0_freq           59.248946
# empstat_3.0_freq           36.686534
# empstat_2.0_freq            4.065574
# dtype: float64

# %%
# Average values of important features for Republican voters
dfr.mean()
# Out:
# inctot                  27325.674755
# mortamt1                  802.162868
# ftotinc                 56267.708946
# marst_5_freq                7.084559
# marst_6_freq               22.259314
# marst_1_freq               55.682966
# marst_4_freq               11.394118
# marst_3_freq                1.647917
# race_2_freq                 7.286275
# race_3_freq                 0.631005
# ctz_stat_3_freq             3.666422
# ctz_stat_2_freq             3.655637
# lang_1_freq                89.632108
# lang_2_freq                10.367892
# educ_attain_2.0_freq       49.350490
# educ_attain_3.0_freq        8.221078
# educ_attain_4.0_freq        0.981005
# empstat_1.0_freq           57.156127
# empstat_3.0_freq           39.433824
# empstat_2.0_freq            3.410907
# dtype: float64
